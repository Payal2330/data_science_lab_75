# %% [markdown]
# <a href="https://colab.research.google.com/github/Payal2330/data_science_lab_75/blob/main/palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check if a number is a palindrome
def is_palindrome(number):
    # Convert the number to a string to easily reverse it
    num_str = str(number)
    # Compare the original string with its reversed version
    return num_str == num_str[::-1]

# Get input from the user
try:
    num = int(input("Enter a number: "))
    if is_palindrome(num):
        print(f"{num} is a palindrome.")
    else:
        print(f"{num} is not a palindrome.")
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a number: 656
# 656 is a palindrome.
