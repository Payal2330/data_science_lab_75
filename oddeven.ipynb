# %% [markdown]
# <a href="https://colab.research.google.com/github/Payal2330/data_science_lab_75/blob/main/oddeven.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Identify Odd or Even Number
#
# The following code snippet will take an integer as input and determine whether it's an odd or even number.

# %%
# Get input from the user
num = int(input("Enter a number: "))

# Check if the number is odd or even using the modulo operator
if (num % 2) == 0:
   print(f"{num} is an even number.")
else:
   print(f"{num} is an odd number.")
# Out:
# Enter a number: 9
# 9 is an odd number.
